# %% [markdown]
# # Building Pipeline

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import pickle
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Suppressing all of the warning

# %%
# Suppress all warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Following are the Functions and each function performs Specific Task

# %%
# Function to import the dataset
def imp(file_path):
    dataframe = pd.read_csv(file_path)
    return dataframe

# Function to check for missing values
def check_null(dataframe):
    datanul = dataframe.isnull().sum()
    missing_cols = [col for col in datanul.index if datanul[col] > 0]
    print(f'\nColumns with missing values: {len(missing_cols)}')
    if len(missing_cols) > 0:
        print(f'Missing values found in columns: {missing_cols}')

# Updated function to select features and handle missing values
def extract_and_display_features(file_path):
    # Load the dataset
    df = pd.read_csv(file_path)

    # List of selected features
    selected_features = ['gene_7705', 'gene_6199', 'gene_6763', 'gene_6963', 'gene_6707', 'gene_6721',
                         'gene_7583', 'gene_7619', 'gene_7913', 'gene_7850', 'gene_7071', 'gene_5788',
                         'gene_7764', 'gene_6185', 'gene_7090', 'gene_7394', 'gene_4593', 'gene_7774',
                         'gene_7755', 'gene_7224', 'gene_6922', 'gene_7954', 'gene_6271', 'gene_4867',
                         'gene_7813', 'gene_7976', 'gene_5809', 'gene_6719', 'gene_6988', 'gene_7428',
                         'gene_7773', 'gene_7922', 'gene_7651', 'gene_5603', 'gene_4079', 'gene_7502',
                         'gene_5544', 'gene_7787', 'gene_7236', 'gene_7953', 'gene_6882', 'gene_7565',
                         'gene_7703', 'gene_7685', 'gene_7333', 'gene_6134', 'gene_7896', 'gene_7277',
                         'gene_7043', 'gene_6445', 'gene_6649', 'gene_6747', 'gene_7307', 'gene_7415',
                         'gene_6403', 'gene_7614', 'gene_7205', 'gene_7766', 'gene_7284', 'gene_7760',
                         'gene_7821', 'gene_5812', 'gene_7898', 'gene_7944', 'gene_7854', 'gene_4338',
                         'gene_7594', 'gene_7048', 'gene_7215', 'gene_7785', 'gene_7864', 'gene_7733',
                         'gene_4937', 'gene_6652', 'gene_7359', 'gene_7422', 'gene_7259', 'gene_6408',
                         'gene_7273', 'gene_6289', 'gene_7297', 'gene_7178', 'gene_7659', 'gene_6182',
                         'gene_4874', 'gene_7476', 'gene_7931', 'gene_7509', 'gene_6377', 'gene_5623',
                         'gene_6827', 'gene_7570', 'gene_7990', 'gene_7212', 'gene_7294', 'gene_7416',
                         'gene_7634', 'gene_7335', 'gene_7838', 'gene_6107', 'gene_7219', 'gene_5549',
                         'gene_7554', 'gene_6256', 'gene_5208', 'gene_7504', 'gene_7871', 'gene_7788',
                         'gene_6421', 'gene_7989', 'gene_7805', 'gene_7835', 'gene_6131', 'gene_7376',
                         'gene_7832', 'gene_7032', 'gene_7361', 'gene_6575', 'gene_4570', 'gene_6904',
                         'gene_6916', 'gene_7720', 'gene_7231', 'gene_7725', 'gene_5861', 'gene_5853',
                         'gene_7563', 'gene_7985']

    # Extract features
    X = df[selected_features]

    # Handle missing values
    imputer = SimpleImputer(strategy='mean')
    X = imputer.fit_transform(X)

    # Convert to DataFrame for better display
    X_df = pd.DataFrame(X, columns=selected_features)

    print("Extracted Features:")
    print(X_df.head())  # Display the first few rows
    return X_df

# Function to load the trained model
def load_model(dataframe):
    model_loaded = pickle.load(open('/content/Updated_Model_For_Cancer_Prediction', 'rb'))
    df = dataframe.drop(columns=['Cancer_Type'])
    print('\nModel is loaded')
    return model_loaded, df

# Function to make predictions
def pred(model_loaded, df):
    print('\nModel predictions are: \n')
    prediction = model_loaded.predict(df)
    return prediction

# Function to convert predictions to a CSV file
def convert_to_csv(prediction, dataframe):
    # Create a DataFrame with the original labels and predicted labels
    dataframe['Predicted_Cancer_Type'] = prediction

    # Display the DataFrame with the predicted labels
    print("Predictions have been added to the DataFrame:")
    print(dataframe[['Cancer_Type', 'Predicted_Cancer_Type']])

    # Save the DataFrame to CSV
    dataframe.to_csv('/content/Predicted_File.csv', index=False)
    print('\nThe entire DataFrame with predictions is saved as a CSV file in /content/ with the name "Predicted_File.csv"')
    return dataframe

# %% [markdown]
# ## Main Function (Pipeline)

# %%
# Main function to run the pipeline
def main(file_path):
    # Load the data
    dataframe = imp(file_path)
    print(dataframe.head())

    # Check for missing values
    check_null(dataframe)

    # Select specified features
    dataframe = extract_and_display_features(file_path)
    dataframe['Cancer_Type'] = imp(file_path)['Cancer_Type']
    print(dataframe.head())

    # Load model and prepare data
    model_loaded, df = load_model(dataframe)
    print(model_loaded)
    print('\n')

    # Make predictions
    prediction = pred(model_loaded, df)
    print(prediction)

    # Convert predictions to CSV and display DataFrame
    predictions_df = convert_to_csv(prediction, dataframe)
    print(predictions_df.head())

# %% [markdown]
# ## Passing Data

# %%
file_path = '/content/cancer_gene_expression2.csv'
if os.path.exists(file_path):
    main(file_path)
else:
    print(f"File not found: {file_path}")
# Out:
#    gene_1  gene_2  gene_3    gene_4  gene_5  gene_6  gene_7  gene_8    gene_9  \
# 0     0.0     0.0     0.0  2.088413     0.0     0.0     0.0     0.0  0.550605
# 1     0.0     0.0     0.0  3.205955     0.0     0.0     0.0     0.0  0.425244
# 2     0.0     0.0     0.0  4.746646     0.0     0.0     0.0     0.0  2.639417
# 3     0.0     0.0     0.0  1.173191     0.0     0.0     0.0     0.0  1.527371
# 4     0.0     0.0     0.0  1.366532     0.0     0.0     0.0     0.0  0.000000
#
#     gene_10  ...  gene_7992  gene_7993  gene_7994  gene_7995  gene_7996  \
# 0  2.815760  ...  11.558803   8.881802   6.014840   6.643534  11.740624
# 1  2.354396  ...  11.062829   9.032864   5.054193   6.432320  12.104985
# 2  1.657091  ...  12.497640   7.198160   0.943434   7.371690  11.202356
# 3  2.732899  ...  11.261713   8.725676   6.300418   6.036451  11.732303
# 4  3.388355  ...  12.241965   7.685204   5.142948   6.355788  11.493950
#
#    gene_7997  gene_7998  gene_7999  gene_8000  Cancer_Type
# 0   7.065012   9.932659   6.928584   2.088413         KIRC
# 1   7.300746   9.872796   5.039231   2.448002         KIRC
# 2   8.426588  11.176890   3.119738   4.433988         BRCA
# 3   7.559469   9.596453   2.863046   3.380342         KIRC
# 4   8.139444  10.189256   6.544487   0.839395         COAD
#
# [5 rows x 8001 columns]
#
# Columns with missing values: 0
# Extracted Features:
#    gene_7705  gene_6199  gene_6763  gene_6963  gene_6707  gene_6721  \
# 0   8.563475  10.615915  10.461398        0.0   4.653266   4.679666
# 1   8.887970  10.369117  10.451252        0.0   0.000000   2.909485
# 2  10.193710  10.256751  10.915476        0.0   1.914258   5.160646
# 3   9.131276  10.614701   9.953139        0.0   3.195048   2.732899
# 4  10.336540  10.927571  10.047969        0.0   2.417110   3.215259
#
#    gene_7583  gene_7619  gene_7913  gene_7850  ...  gene_4570  gene_6904  \
# 0   0.550605   8.646119   5.323136   8.156776  ...   9.059420   9.393322
# 1   0.000000   8.133091   4.519812   6.599749  ...   9.582166   9.310317
# 2   0.691891   7.328154   1.657091   3.799409  ...   8.607045  10.360002
# 3   0.000000   8.531378   4.773843   6.600137  ...  10.211657   9.862681
# 4   0.839395  11.628787   4.288934   7.176383  ...   9.264558  10.429470
#
#    gene_6916  gene_7720  gene_7231  gene_7725  gene_5861  gene_5853  \
# 0   0.000000   9.619870   7.089043   9.694535   9.217548   7.609090
# 1   1.020413   9.395245   7.837937  10.851484   9.304073   8.272364
# 2   2.639417   8.373583   6.829025   9.853310   9.195325   6.255210
# 3   1.173191   9.454149   6.235695   8.900680   9.920813   7.052948
# 4   4.346035   7.964428   4.936643   8.303402  10.716759   7.103739
#
#    gene_7563  gene_7985
# 0        0.0   9.596626
# 1        0.0   9.993179
# 2        0.0   3.594178
# 3        0.0   8.889267
# 4        0.0   6.020824
#
# [5 rows x 128 columns]
#    gene_7705  gene_6199  gene_6763  gene_6963  gene_6707  gene_6721  \
# 0   8.563475  10.615915  10.461398        0.0   4.653266   4.679666
# 1   8.887970  10.369117  10.451252        0.0   0.000000   2.909485
# 2  10.193710  10.256751  10.915476        0.0   1.914258   5.160646
# 3   9.131276  10.614701   9.953139        0.0   3.195048   2.732899
# 4  10.336540  10.927571  10.047969        0.0   2.417110   3.215259
#
#    gene_7583  gene_7619  gene_7913  gene_7850  ...  gene_6904  gene_6916  \
# 0   0.550605   8.646119   5.323136   8.156776  ...   9.393322   0.000000
# 1   0.000000   8.133091   4.519812   6.599749  ...   9.310317   1.020413
# 2   0.691891   7.328154   1.657091   3.799409  ...  10.360002   2.639417
# 3   0.000000   8.531378   4.773843   6.600137  ...   9.862681   1.173191
# 4   0.839395  11.628787   4.288934   7.176383  ...  10.429470   4.346035
#
#    gene_7720  gene_7231  gene_7725  gene_5861  gene_5853  gene_7563  \
# 0   9.619870   7.089043   9.694535   9.217548   7.609090        0.0
# 1   9.395245   7.837937  10.851484   9.304073   8.272364        0.0
# 2   8.373583   6.829025   9.853310   9.195325   6.255210        0.0
# 3   9.454149   6.235695   8.900680   9.920813   7.052948        0.0
# 4   7.964428   4.936643   8.303402  10.716759   7.103739        0.0
#
#    gene_7985  Cancer_Type
# 0   9.596626         KIRC
# 1   9.993179         KIRC
# 2   3.594178         BRCA
# 3   8.889267         KIRC
# 4   6.020824         COAD
#
# [5 rows x 129 columns]
#
# Model is loaded
# GradientBoostingClassifier(learning_rate=0.05, max_depth=4, n_estimators=200)
#
#
#
# Model predictions are:
#
# ['KIRC' 'KIRC' 'BRCA' 'KIRC' 'COAD' 'LUAD' 'KIRC' 'LUAD' 'BRCA' 'COAD'
#  'PRAD' 'BRCA' 'PRAD' 'PRAD' 'KIRC' 'PRAD' 'KIRC' 'LUAD' 'LUAD' 'PRAD'
#  'BRCA' 'COAD' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'BRCA' 'KIRC' 'KIRC' 'BRCA'
#  'BRCA' 'BRCA' 'BRCA' 'COAD' 'KIRC' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'PRAD'
#  'BRCA' 'BRCA' 'COAD' 'BRCA' 'LUAD' 'KIRC' 'COAD' 'COAD' 'KIRC' 'BRCA'
#  'PRAD' 'COAD' 'BRCA' 'LUAD' 'LUAD' 'PRAD' 'LUAD' 'BRCA' 'BRCA' 'PRAD'
#  'LUAD' 'PRAD' 'BRCA' 'PRAD' 'LUAD' 'BRCA' 'COAD' 'KIRC' 'KIRC' 'BRCA'
#  'KIRC' 'COAD' 'BRCA' 'PRAD' 'KIRC' 'BRCA' 'PRAD' 'LUAD' 'COAD' 'KIRC'
#  'KIRC' 'BRCA' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'PRAD' 'LUAD' 'BRCA' 'LUAD'
#  'PRAD' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'PRAD' 'KIRC' 'BRCA' 'PRAD'
#  'LUAD' 'LUAD' 'KIRC' 'BRCA' 'BRCA' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'BRCA'
#  'BRCA' 'KIRC' 'LUAD' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'BRCA' 'COAD'
#  'KIRC' 'COAD' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'BRCA' 'BRCA' 'BRCA' 'BRCA'
#  'COAD' 'BRCA' 'COAD' 'BRCA' 'BRCA' 'BRCA' 'LUAD' 'BRCA' 'BRCA' 'KIRC'
#  'BRCA' 'LUAD' 'BRCA' 'COAD' 'PRAD' 'COAD' 'LUAD' 'COAD' 'LUAD' 'BRCA'
#  'COAD' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'COAD' 'COAD' 'LUAD' 'LUAD' 'PRAD'
#  'LUAD' 'BRCA' 'LUAD' 'KIRC' 'BRCA' 'KIRC' 'BRCA' 'LUAD' 'BRCA' 'LUAD'
#  'KIRC' 'KIRC' 'LUAD' 'BRCA' 'BRCA' 'BRCA' 'LUAD' 'KIRC' 'COAD' 'LUAD'
#  'BRCA' 'BRCA' 'LUAD' 'BRCA' 'PRAD' 'PRAD' 'LUAD' 'COAD' 'BRCA' 'BRCA'
#  'BRCA' 'PRAD' 'COAD' 'BRCA' 'PRAD' 'BRCA' 'PRAD' 'COAD' 'BRCA' 'PRAD'
#  'KIRC' 'PRAD' 'PRAD' 'BRCA' 'LUAD' 'BRCA' 'LUAD' 'BRCA' 'BRCA' 'KIRC'
#  'KIRC' 'LUAD' 'KIRC' 'LUAD' 'PRAD' 'BRCA' 'KIRC' 'LUAD' 'LUAD' 'COAD'
#  'LUAD' 'BRCA' 'PRAD' 'LUAD' 'BRCA' 'COAD' 'LUAD' 'KIRC' 'PRAD' 'BRCA'
#  'BRCA' 'PRAD' 'LUAD' 'KIRC' 'PRAD' 'BRCA' 'PRAD' 'KIRC' 'BRCA' 'KIRC'
#  'LUAD' 'BRCA' 'LUAD' 'BRCA' 'KIRC' 'PRAD' 'BRCA' 'KIRC' 'PRAD' 'BRCA'
#  'BRCA' 'PRAD' 'LUAD' 'LUAD' 'BRCA' 'LUAD' 'BRCA' 'KIRC' 'BRCA' 'BRCA'
#  'BRCA' 'BRCA' 'PRAD' 'KIRC' 'KIRC' 'PRAD' 'BRCA' 'LUAD' 'BRCA' 'BRCA'
#  'BRCA' 'PRAD' 'LUAD' 'BRCA' 'BRCA' 'KIRC' 'LUAD' 'KIRC' 'LUAD' 'PRAD'
#  'LUAD' 'COAD' 'BRCA' 'BRCA' 'LUAD' 'KIRC' 'BRCA' 'COAD' 'BRCA' 'PRAD'
#  'LUAD' 'COAD' 'COAD' 'COAD' 'KIRC' 'LUAD' 'KIRC' 'COAD' 'BRCA' 'BRCA'
#  'LUAD' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'LUAD' 'KIRC' 'PRAD'
#  'COAD' 'LUAD' 'KIRC' 'BRCA' 'LUAD' 'PRAD' 'PRAD' 'BRCA' 'KIRC' 'PRAD'
#  'BRCA' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'PRAD' 'BRCA' 'KIRC' 'BRCA'
#  'BRCA' 'KIRC' 'PRAD' 'PRAD' 'BRCA' 'LUAD' 'LUAD' 'BRCA' 'LUAD' 'LUAD'
#  'BRCA' 'COAD' 'BRCA' 'LUAD' 'KIRC' 'PRAD' 'LUAD' 'BRCA' 'PRAD' 'BRCA'
#  'LUAD' 'BRCA' 'LUAD' 'BRCA' 'KIRC' 'BRCA' 'PRAD' 'BRCA' 'PRAD' 'COAD'
#  'KIRC' 'LUAD' 'BRCA' 'PRAD' 'PRAD' 'PRAD' 'COAD' 'BRCA' 'KIRC' 'BRCA'
#  'BRCA' 'BRCA' 'LUAD' 'KIRC' 'COAD' 'KIRC' 'BRCA' 'PRAD' 'LUAD' 'KIRC'
#  'KIRC' 'PRAD' 'COAD' 'BRCA' 'COAD' 'BRCA' 'BRCA' 'PRAD' 'BRCA' 'BRCA'
#  'PRAD' 'KIRC' 'KIRC' 'LUAD' 'BRCA' 'KIRC' 'LUAD' 'BRCA' 'LUAD' 'KIRC'
#  'LUAD' 'BRCA' 'BRCA' 'PRAD' 'BRCA' 'KIRC' 'KIRC' 'LUAD' 'KIRC' 'BRCA'
#  'COAD' 'BRCA' 'BRCA' 'PRAD' 'BRCA' 'KIRC' 'BRCA' 'BRCA' 'KIRC' 'BRCA'
#  'BRCA' 'KIRC' 'PRAD' 'BRCA' 'COAD' 'KIRC' 'BRCA' 'KIRC' 'COAD' 'BRCA'
#  'LUAD' 'BRCA' 'KIRC' 'BRCA' 'KIRC' 'KIRC' 'BRCA' 'LUAD' 'BRCA' 'LUAD'
#  'PRAD' 'KIRC' 'BRCA' 'PRAD' 'BRCA' 'LUAD' 'BRCA' 'BRCA' 'COAD' 'KIRC'
#  'BRCA' 'KIRC' 'PRAD' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'KIRC'
#  'LUAD' 'BRCA' 'PRAD' 'LUAD' 'PRAD' 'PRAD' 'PRAD' 'PRAD' 'KIRC' 'BRCA'
#  'LUAD' 'PRAD' 'LUAD' 'BRCA' 'BRCA' 'PRAD' 'LUAD' 'BRCA' 'BRCA' 'BRCA'
#  'LUAD' 'LUAD' 'PRAD' 'PRAD' 'PRAD' 'BRCA' 'LUAD' 'COAD' 'BRCA' 'PRAD'
#  'BRCA' 'BRCA' 'KIRC' 'KIRC' 'BRCA' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'BRCA'
#  'BRCA' 'LUAD' 'COAD' 'BRCA' 'LUAD' 'KIRC' 'KIRC' 'COAD' 'BRCA' 'BRCA'
#  'PRAD' 'LUAD' 'BRCA' 'PRAD' 'COAD' 'COAD' 'PRAD' 'KIRC' 'KIRC' 'LUAD'
#  'LUAD' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'KIRC' 'PRAD' 'KIRC' 'BRCA' 'BRCA'
#  'KIRC' 'LUAD' 'LUAD' 'PRAD' 'KIRC' 'PRAD' 'PRAD' 'COAD' 'KIRC' 'PRAD'
#  'BRCA' 'LUAD' 'BRCA' 'BRCA' 'BRCA' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'BRCA'
#  'BRCA' 'BRCA' 'PRAD' 'PRAD' 'COAD' 'PRAD' 'PRAD' 'PRAD' 'KIRC' 'KIRC'
#  'KIRC' 'BRCA' 'BRCA' 'COAD' 'LUAD' 'BRCA' 'COAD' 'LUAD' 'KIRC' 'LUAD'
#  'LUAD' 'BRCA' 'PRAD' 'LUAD' 'BRCA' 'LUAD' 'KIRC' 'BRCA' 'LUAD' 'KIRC'
#  'BRCA' 'BRCA' 'KIRC' 'KIRC' 'BRCA' 'COAD' 'BRCA' 'LUAD' 'KIRC' 'LUAD'
#  'BRCA' 'BRCA' 'LUAD' 'KIRC' 'COAD' 'PRAD' 'BRCA' 'PRAD' 'KIRC' 'KIRC'
#  'BRCA' 'COAD' 'KIRC' 'BRCA' 'KIRC' 'PRAD' 'BRCA' 'BRCA' 'PRAD' 'PRAD'
#  'BRCA' 'LUAD' 'LUAD' 'BRCA' 'LUAD' 'BRCA' 'LUAD' 'BRCA' 'PRAD' 'BRCA'
#  'KIRC' 'BRCA' 'COAD' 'PRAD' 'COAD' 'KIRC' 'PRAD' 'LUAD' 'KIRC' 'PRAD'
#  'BRCA' 'COAD' 'BRCA' 'LUAD' 'BRCA' 'COAD' 'BRCA' 'BRCA' 'PRAD' 'BRCA'
#  'PRAD' 'COAD' 'BRCA' 'KIRC' 'BRCA' 'LUAD' 'PRAD' 'COAD' 'PRAD' 'LUAD'
#  'BRCA' 'LUAD' 'COAD' 'COAD' 'KIRC' 'BRCA' 'KIRC' 'LUAD' 'LUAD' 'LUAD'
#  'BRCA' 'BRCA' 'COAD' 'PRAD' 'PRAD' 'KIRC' 'BRCA' 'LUAD' 'KIRC' 'BRCA'
#  'BRCA' 'BRCA' 'KIRC' 'BRCA' 'BRCA' 'BRCA' 'LUAD' 'PRAD' 'BRCA' 'BRCA'
#  'KIRC' 'LUAD' 'COAD' 'LUAD' 'KIRC' 'LUAD' 'BRCA' 'BRCA' 'PRAD' 'BRCA'
#  'PRAD' 'COAD' 'BRCA' 'BRCA' 'BRCA' 'COAD' 'LUAD' 'BRCA' 'KIRC' 'LUAD'
#  'PRAD' 'BRCA' 'BRCA' 'BRCA' 'KIRC' 'COAD' 'BRCA' 'PRAD' 'PRAD' 'BRCA'
#  'BRCA' 'BRCA' 'PRAD' 'COAD' 'KIRC' 'LUAD' 'BRCA' 'KIRC' 'LUAD' 'BRCA'
#  'BRCA' 'LUAD' 'BRCA' 'KIRC' 'BRCA' 'PRAD' 'COAD' 'KIRC' 'KIRC' 'BRCA'
#  'KIRC' 'PRAD' 'PRAD' 'PRAD' 'BRCA' 'BRCA' 'PRAD' 'LUAD' 'LUAD' 'PRAD'
#  'LUAD' 'LUAD' 'BRCA' 'PRAD' 'BRCA' 'COAD' 'PRAD' 'LUAD' 'KIRC' 'BRCA'
#  'KIRC' 'BRCA' 'PRAD' 'KIRC' 'PRAD' 'BRCA' 'PRAD' 'KIRC' 'BRCA' 'PRAD'
#  'PRAD' 'BRCA' 'LUAD' 'KIRC' 'PRAD' 'PRAD' 'BRCA' 'LUAD' 'KIRC' 'LUAD'
#  'BRCA' 'LUAD' 'BRCA' 'KIRC' 'PRAD' 'KIRC' 'LUAD' 'BRCA' 'LUAD' 'PRAD'
#  'BRCA' 'LUAD' 'PRAD' 'BRCA' 'LUAD' 'LUAD' 'BRCA' 'BRCA' 'BRCA' 'PRAD'
#  'BRCA' 'KIRC' 'PRAD' 'PRAD' 'BRCA' 'BRCA' 'BRCA' 'COAD' 'BRCA' 'BRCA'
#  'COAD']
# Predictions have been added to the DataFrame:
#     Cancer_Type Predicted_Cancer_Type
# 0          KIRC                  KIRC
# 1          KIRC                  KIRC
# 2          BRCA                  BRCA
# 3          KIRC                  KIRC
# 4          COAD                  COAD
# ..          ...                   ...
# 796        BRCA                  BRCA
# 797        COAD                  COAD
# 798        BRCA                  BRCA
# 799        BRCA                  BRCA
# 800        COAD                  COAD
#
# [801 rows x 2 columns]
#
# The entire DataFrame with predictions is saved as a CSV file in /content/ with the name "Predicted_File.csv"
#    gene_7705  gene_6199  gene_6763  gene_6963  gene_6707  gene_6721  \
# 0   8.563475  10.615915  10.461398        0.0   4.653266   4.679666
# 1   8.887970  10.369117  10.451252        0.0   0.000000   2.909485
# 2  10.193710  10.256751  10.915476        0.0   1.914258   5.160646
# 3   9.131276  10.614701   9.953139        0.0   3.195048   2.732899
# 4  10.336540  10.927571  10.047969        0.0   2.417110   3.215259
#
#    gene_7583  gene_7619  gene_7913  gene_7850  ...  gene_6916  gene_7720  \
# 0   0.550605   8.646119   5.323136   8.156776  ...   0.000000   9.619870
# 1   0.000000   8.133091   4.519812   6.599749  ...   1.020413   9.395245
# 2   0.691891   7.328154   1.657091   3.799409  ...   2.639417   8.373583
# 3   0.000000   8.531378   4.773843   6.600137  ...   1.173191   9.454149
# 4   0.839395  11.628787   4.288934   7.176383  ...   4.346035   7.964428
#
#    gene_7231  gene_7725  gene_5861  gene_5853  gene_7563  gene_7985  \
# 0   7.089043   9.694535   9.217548   7.609090        0.0   9.596626
# 1   7.837937  10.851484   9.304073   8.272364        0.0   9.993179
# 2   6.829025   9.853310   9.195325   6.255210        0.0   3.594178
# 3   6.235695   8.900680   9.920813   7.052948        0.0   8.889267
# 4   4.936643   8.303402  10.716759   7.103739        0.0   6.020824
#
#    Cancer_Type  Predicted_Cancer_Type
# 0         KIRC                   KIRC
# 1         KIRC                   KIRC
# 2         BRCA                   BRCA
# 3         KIRC                   KIRC
# 4         COAD                   COAD
#
# [5 rows x 130 columns]
